# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Nyameko Lolwana__
#
# Desired -  Data Analyst

# %% [markdown]
# *I am interested in data science because I have realized how passionate I am with data analytics based on the projects I have worked on in my current role and how valuable data is and my contribution would be to the success of the market I'm in.*

# %% [markdown]
# ### Concatenating and displaying my full name

# %%
Name = "Nyameko"
Surname = "Lolwana"
print(Name +" "+ Surname)
# Out:
# Nyameko Lolwana

# %% [markdown]
# https://www.coursera.org/learn/open-source-tools-for-data-science/home/week/2
#
# ![image.png](attachment:image.png)
#
#
#
# ~~Don't give up~~
